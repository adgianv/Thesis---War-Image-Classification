# %% [markdown]
# Notebook to convert data into panel format for regressions

# %%
import pandas as pd

# %%
# Load aggregated dataframes
month_agg = pd.read_csv('data/aggregated_data.csv')
week_agg = pd.read_csv('data/aggregated_data_weekly.csv')

# %%
month_agg.head()
# Out:
#    Unnamed: 0  year_month  launched  share_with_ukraine  \
# 0           0  2022-12-01     364.0            0.068872
# 1           1  2023-01-01     213.0            0.102060
# 2           2  2023-02-01     193.0            0.141184
# 3           3  2023-03-01     181.0            0.090881
# 4           4  2023-04-01     117.0            0.072224
#
#    a3_share_with_ukraine  la6_share_with_ukraine  t5_share_with_ukraine  \
# 0               0.091422                0.059908               0.058140
# 1               0.147257                0.079872               0.079861
# 2               0.195722                0.100925               0.137572
# 3               0.111977                0.076399               0.088000
# 4               0.091097                0.061329               0.065614
#
#    fatalities  a3_war_share_out_of_total  la6_war_share_out_of_total  \
# 0        2174                   0.020691                    0.013054
# 1        1187                   0.021963                    0.025506
# 2         665                   0.035792                    0.021755
# 3         866                   0.027419                    0.019478
# 4        1135                   0.021889                    0.014657
#
#    t5_war_share_out_of_total  combined_war_share_out_of_total  \
# 0                   0.011542                         0.014037
# 1                   0.023688                         0.024198
# 2                   0.027630                         0.025175
# 3                   0.024133                         0.021417
# 4                   0.018935                         0.017272
#
#    a3_share_class_1  la6_share_class_1  t5_share_class_1  total_share_class_1
# 0          0.178934           0.208306          0.196842             0.196247
# 1          0.254697           0.317797          0.293921             0.296647
# 2          0.210837           0.215436          0.199777             0.207990
# 3          0.281768           0.254028          0.271830             0.262083
# 4          0.218646           0.251767          0.286108             0.257773

# %%
week_agg.head()
# Out:
#    Unnamed: 0        week  launched  share_with_ukraine  \
# 0           0  2022-12-05      99.0            0.082557
# 1           1  2022-12-12     116.0            0.038674
# 2           2  2022-12-19      38.0            0.088710
# 3           3  2022-12-26     156.0            0.077961
# 4           4  2023-01-02      41.0            0.076590
#
#    a3_share_with_ukraine  la6_share_with_ukraine  t5_share_with_ukraine  \
# 0               0.082251                0.081761               0.084158
# 1               0.048458                0.046429               0.018433
# 2               0.115000                0.072581               0.081395
# 3               0.131250                0.051351               0.087591
# 4               0.074257                0.088123               0.065502
#
#    fatalities  a3_war_share_out_of_total  la6_war_share_out_of_total  \
# 0         313                   0.018939                    0.017505
# 1         282                   0.007407                    0.007884
# 2         646                   0.018333                    0.018481
# 3         972                   0.025850                    0.011040
# 4         211                   0.007284                    0.024266
#
#    t5_war_share_out_of_total  count_class_one  total_seconds  \
# 0                   0.012624            562.0          35160
# 1                   0.004608            190.0          29640
# 2                   0.016279            663.0          37200
# 3                   0.025791            570.0          32760
# 4                   0.012809            615.0          37500
#
#    combined_war_share_out_of_total  a3_share_class_1  la6_share_class_1  \
# 0                         0.015984          0.155602           0.213146
# 1                         0.006410          0.262295           0.171946
# 2                         0.017823          0.159074           0.253223
# 3                         0.017399          0.168701           0.189512
# 4                         0.016400          0.122661           0.274368
#
#    t5_share_class_1  total_share_class_1
# 0          0.148833             0.182645
# 1          0.246914             0.196484
# 2          0.198582             0.200000
# 3          0.292414             0.210100
# 4          0.193407             0.221542

# %%
# Drop cols which are aggregated across channel
month_agg = month_agg.drop(['share_with_ukraine', 'total_share_class_1', 'combined_war_share_out_of_total'], axis=1)
week_agg = week_agg.drop(['share_with_ukraine', 'total_share_class_1', 'combined_war_share_out_of_total'], axis=1)

# %% [markdown]
# Convert month df to panel

# %%
# Melting the dataframe to long format
df_long = pd.melt(month_agg, id_vars=['year_month', 'launched', 'fatalities'],
                  value_vars=['a3_share_with_ukraine', 'la6_share_with_ukraine', 't5_share_with_ukraine', 
                              'a3_share_class_1', 'la6_share_class_1', 't5_share_class_1',
                              'a3_war_share_out_of_total', 'la6_war_share_out_of_total', 't5_war_share_out_of_total'],
                  var_name='type', value_name='value')

# Extracting the 'a3', 't5', 'la6' part and the share type part
df_long[['share_type', 'type']] = df_long['type'].str.extract(r'(a3|la6|t5)_(.*)')

# Pivoting the dataframe to wide format again
df_panel = df_long.pivot_table(index=['year_month', 'launched', 'fatalities', 'share_type'], 
                               columns='type', values='value').reset_index()

# Reordering the columns
df_panel_month = df_panel[['year_month', 'share_type', 'launched', 
                     'share_with_ukraine', 'fatalities', 'share_class_1', 'war_share_out_of_total']]

# Renaming columns
df_panel_month.columns = ['year_month', 'channel', 'launched', 
                    'coverage', 'fatalities', 'war_images', 'war_share_out_of_total']

# %%
df_panel_month
# Out:
#     year_month channel  launched  coverage  fatalities  war_images  \
# 0   2022-12-01      a3     364.0  0.091422        2174    0.178934
# 1   2022-12-01     la6     364.0  0.059908        2174    0.208306
# 2   2022-12-01      t5     364.0  0.058140        2174    0.196842
# 3   2023-01-01      a3     213.0  0.147257        1187    0.254697
# 4   2023-01-01     la6     213.0  0.079872        1187    0.317797
# 5   2023-01-01      t5     213.0  0.079861        1187    0.293921
# 6   2023-02-01      a3     193.0  0.195722         665    0.210837
# 7   2023-02-01     la6     193.0  0.100925         665    0.215436
# 8   2023-02-01      t5     193.0  0.137572         665    0.199777
# 9   2023-03-01      a3     181.0  0.111977         866    0.281768
# 10  2023-03-01     la6     181.0  0.076399         866    0.254028
# 11  2023-03-01      t5     181.0  0.088000         866    0.271830
# 12  2023-04-01      a3     117.0  0.091097        1135    0.218646
# 13  2023-04-01     la6     117.0  0.061329        1135    0.251767
# 14  2023-04-01      t5     117.0  0.065614        1135    0.286108
# 15  2023-05-01      a3     667.0  0.104142        1434    0.212911
# 16  2023-05-01     la6     667.0  0.041783        1434    0.205969
# 17  2023-05-01      t5     667.0  0.062718        1434    0.249771
# 18  2023-06-01      a3     447.0  0.092191        1243    0.212318
# 19  2023-06-01     la6     447.0  0.046229        1243    0.195870
# 20  2023-06-01      t5     447.0  0.061576        1243    0.175752
# 21  2023-07-01      a3     433.0  0.067678         939    0.215226
# 22  2023-07-01     la6     433.0  0.069231         939    0.188818
# 23  2023-07-01      t5     433.0  0.059783         939    0.219500
# 24  2023-08-01      a3     324.0  0.050766         784    0.216765
# 25  2023-08-01     la6     324.0  0.034461         784    0.233600
# 26  2023-08-01      t5     324.0  0.041725         784    0.275729
# 27  2023-09-01      a3     621.0  0.060023         803    0.161406
# 28  2023-09-01     la6     621.0  0.041176         803    0.151186
# 29  2023-09-01      t5     621.0  0.039526         803    0.263621
# 30  2023-10-01      a3     347.0  0.030660         746    0.188867
# 31  2023-10-01     la6     347.0  0.019393         746    0.159846
# 32  2023-10-01      t5     347.0  0.028969         746    0.219802
# 33  2023-11-01      a3     432.0  0.019408         792    0.110627
# 34  2023-11-01     la6     432.0  0.023669         792    0.110766
# 35  2023-11-01      t5     432.0  0.012626         792    0.179572
# 36  2023-12-01      a3     840.0  0.046748         615    0.169253
# 37  2023-12-01     la6     840.0  0.030598         615    0.188914
# 38  2023-12-01      t5     840.0  0.025210         615    0.220803
# 39  2024-01-01      a3     677.0  0.036585         677    0.215784
# 40  2024-01-01     la6     677.0  0.020185         677    0.199036
# 41  2024-01-01      t5     677.0  0.013462         677    0.204706
# 42  2024-02-01      a3     523.0  0.072816         923    0.135357
# 43  2024-02-01     la6     523.0  0.034589         923    0.171650
# 44  2024-02-01      t5     523.0  0.080503         923    0.174464
# 45  2024-03-01      a3     849.0  0.093842         584    0.148196
# 46  2024-03-01     la6     849.0  0.054995         584    0.164220
# 47  2024-03-01      t5     849.0  0.071656         584    0.158339
# 48  2024-04-01      a3     505.0  0.027273         731    0.191339
# 49  2024-04-01     la6     505.0  0.028005         731    0.318370
# 50  2024-04-01      t5     505.0  0.019174         731    0.253485
#
#     war_share_out_of_total
# 0                 0.020691
# 1                 0.013054
# 2                 0.011542
# 3                 0.021963
# 4                 0.025506
# 5                 0.023688
# 6                 0.035792
# 7                 0.021755
# 8                 0.027630
# 9                 0.027419
# 10                0.019478
# 11                0.024133
# 12                0.021889
# 13                0.014657
# 14                0.018935
# 15                0.022249
# 16                0.008651
# 17                0.015815
# 18                0.019603
# 19                0.008975
# 20                0.010920
# 21                0.013862
# 22                0.013365
# 23                0.013255
# 24                0.010881
# 25                0.007900
# 26                0.011613
# 27                0.009646
# 28                0.006246
# 29                0.010518
# 30                0.005843
# 31                0.003016
# 32                0.006431
# 33                0.002162
# 34                0.002638
# 35                0.002294
# 36                0.007944
# 37                0.005807
# 38                0.005649
# 39                0.007947
# 40                0.004051
# 41                0.002788
# 42                0.009887
# 43                0.005957
# 44                0.014151
# 45                0.013954
# 46                0.009059
# 47                0.011438
# 48                0.005260
# 49                0.008965
# 50                0.004916

# %% [markdown]
# Convert week df to panel

# %%
# Melting the dataframe to long format
df_long = pd.melt(week_agg, id_vars=['week', 'launched', 'fatalities'],
                  value_vars=['a3_share_with_ukraine', 'la6_share_with_ukraine', 't5_share_with_ukraine', 
                              'a3_share_class_1', 'la6_share_class_1', 't5_share_class_1',
                              'a3_war_share_out_of_total', 'la6_war_share_out_of_total', 't5_war_share_out_of_total'],
                  var_name='type', value_name='value')

# Extracting the 'a3', 't5', 'la6' part and the share type part
df_long[['share_type', 'type']] = df_long['type'].str.extract(r'(a3|la6|t5)_(.*)')

# Pivoting the dataframe to wide format again
df_panel = df_long.pivot_table(index=['week', 'launched', 'fatalities', 'share_type'], 
                               columns='type', values='value').reset_index()

# Reordering the columns
df_panel_week = df_panel[['week', 'share_type', 'launched', 
                     'share_with_ukraine', 'fatalities', 'share_class_1', 'war_share_out_of_total']]

# Renaming columns
df_panel_week.columns = ['week', 'channel', 'launched', 
                    'coverage', 'fatalities', 'war_images', 'war_share_out_of_total']

# %%
df_panel_week
# Out:
#            week channel  launched  coverage  fatalities  war_images  \
# 0    2022-12-05      a3      99.0  0.082251         313    0.155602
# 1    2022-12-05     la6      99.0  0.081761         313    0.213146
# 2    2022-12-05      t5      99.0  0.084158         313    0.148833
# 3    2022-12-12      a3     116.0  0.048458         282    0.262295
# 4    2022-12-12     la6     116.0  0.046429         282    0.171946
# ..          ...     ...       ...       ...         ...         ...
# 210  2024-04-22      a3      92.0  0.030973         135    0.204276
# 211  2024-04-22     la6      92.0  0.056818         135    0.281457
# 212  2024-04-22      t5      92.0  0.000000         135    0.327869
# 213  2024-04-29      a3      56.0  0.032258          67    0.267081
# 214  2024-04-29      t5      56.0       NaN          67    0.049180
#
#      war_share_out_of_total
# 0                  0.018939
# 1                  0.017505
# 2                  0.012624
# 3                  0.007407
# 4                  0.007884
# ..                      ...
# 210                0.006342
# 211                0.016098
# 212                0.005435
# 213                0.006183
# 214                0.000000
#
# [215 rows x 7 columns]

# %% [markdown]
# Save dataframes

# %%
df_panel_month.to_csv('data/monthly_panel.csv', index=False)
df_panel_week.to_csv('data/weekly_panel.csv', index=False)
