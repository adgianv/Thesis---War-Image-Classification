# %% [markdown]
# Notebook to convert data into panel format for regressions

# %%
import pandas as pd

# %%
# Load aggregated dataframes
month_agg = pd.read_csv('data/aggregated_data.csv')
week_agg = pd.read_csv('data/aggregated_data_weekly.csv')

# %%
month_agg.head()
# Out:
#    Unnamed: 0  year_month  launched  share_with_ukraine  \
# 0           0  2022-12-01     364.0            0.068872
# 1           1  2023-01-01     213.0            0.102060
# 2           2  2023-02-01     193.0            0.141184
# 3           3  2023-03-01     181.0            0.090881
# 4           4  2023-04-01     117.0            0.072224
#
#    a3_share_with_ukraine  la6_share_with_ukraine  t5_share_with_ukraine  \
# 0               0.091422                0.059908               0.058140
# 1               0.147257                0.079872               0.079861
# 2               0.195722                0.100925               0.137572
# 3               0.111977                0.076399               0.088000
# 4               0.091097                0.061329               0.065614
#
#    fatalities  a3_war_share_out_of_total  la6_war_share_out_of_total  \
# 0        2174                   0.019943                    0.013344
# 1        1187                   0.022056                    0.025839
# 2         665                   0.037432                    0.021755
# 3         866                   0.025806                    0.019705
# 4        1135                   0.022167                    0.013754
#
#    t5_war_share_out_of_total  combined_war_share_out_of_total  \
# 0                   0.011649                         0.014071
# 1                   0.025656                         0.025016
# 2                   0.028227                         0.025540
# 3                   0.025962                         0.022247
# 4                   0.018753                         0.016805
#
#    a3_share_class_1  la6_share_class_1  t5_share_class_1  total_share_class_1
# 0          0.172467           0.212945          0.198678             0.196723
# 1          0.255780           0.321944          0.318334             0.306667
# 2          0.220494           0.215436          0.204096             0.211006
# 3          0.265193           0.256988          0.292427             0.272245
# 4          0.221421           0.236270          0.283354             0.250800

# %%
week_agg.head()
# Out:
#    Unnamed: 0        week  launched  share_with_ukraine  \
# 0           0  2022-12-05      99.0            0.082557
# 1           1  2022-12-12     116.0            0.038674
# 2           2  2022-12-19      38.0            0.088710
# 3           3  2022-12-26     156.0            0.077961
# 4           4  2023-01-02      41.0            0.076590
#
#    a3_share_with_ukraine  la6_share_with_ukraine  t5_share_with_ukraine  \
# 0               0.082251                0.081761               0.084158
# 1               0.048458                0.046429               0.018433
# 2               0.115000                0.072581               0.081395
# 3               0.131250                0.051351               0.087591
# 4               0.074257                0.088123               0.065502
#
#    fatalities  a3_war_share_out_of_total  la6_war_share_out_of_total  \
# 0         313                   0.017424                    0.018501
# 1         282                   0.006019                    0.007953
# 2         646                   0.016417                    0.017675
# 3         972                   0.028061                    0.011468
# 4         211                   0.006173                    0.021201
#
#    t5_war_share_out_of_total  count_class_one  total_seconds  \
# 0                   0.013284            583.0          35160
# 1                   0.004147            182.0          29640
# 2                   0.015213            617.0          37200
# 3                   0.028102            610.0          32760
# 4                   0.013173            563.0          37500
#
#    combined_war_share_out_of_total  a3_share_class_1  la6_share_class_1  \
# 0                         0.016581          0.143154           0.225271
# 1                         0.006140          0.213115           0.173454
# 2                         0.016586          0.142444           0.242173
# 3                         0.018620          0.183130           0.196872
# 4                         0.015013          0.103950           0.239711
#
#    t5_share_class_1  total_share_class_1
# 0          0.156615             0.189470
# 1          0.222222             0.188211
# 2          0.185579             0.186124
# 3          0.318621             0.224843
# 4          0.198901             0.202810

# %%
# Drop cols which are aggregated across channel
month_agg = month_agg.drop(['share_with_ukraine', 'total_share_class_1', 'combined_war_share_out_of_total'], axis=1)
week_agg = week_agg.drop(['share_with_ukraine', 'total_share_class_1', 'combined_war_share_out_of_total'], axis=1)

# %% [markdown]
# Convert month df to panel

# %%
# Melting the dataframe to long format
df_long = pd.melt(month_agg, id_vars=['year_month', 'launched', 'fatalities'],
                  value_vars=['a3_share_with_ukraine', 'la6_share_with_ukraine', 't5_share_with_ukraine', 
                              'a3_share_class_1', 'la6_share_class_1', 't5_share_class_1',
                              'a3_war_share_out_of_total', 'la6_war_share_out_of_total', 't5_war_share_out_of_total'],
                  var_name='type', value_name='value')

# Extracting the 'a3', 't5', 'la6' part and the share type part
df_long[['share_type', 'type']] = df_long['type'].str.extract(r'(a3|la6|t5)_(.*)')

# Pivoting the dataframe to wide format again
df_panel = df_long.pivot_table(index=['year_month', 'launched', 'fatalities', 'share_type'], 
                               columns='type', values='value').reset_index()

# Reordering the columns
df_panel_month = df_panel[['year_month', 'share_type', 'launched', 
                     'share_with_ukraine', 'fatalities', 'share_class_1', 'war_share_out_of_total']]

# Renaming columns
df_panel_month.columns = ['year_month', 'channel', 'launched', 
                    'coverage', 'fatalities', 'war_images', 'war_share_out_of_total']

# %%
df_panel_month
# Out:
#     year_month channel  launched  coverage  fatalities  war_images  \
# 0   2022-12-01      a3     364.0  0.091422        2174    0.172467
# 1   2022-12-01     la6     364.0  0.059908        2174    0.212945
# 2   2022-12-01      t5     364.0  0.058140        2174    0.198678
# 3   2023-01-01      a3     213.0  0.147257        1187    0.255780
# 4   2023-01-01     la6     213.0  0.079872        1187    0.321944
# 5   2023-01-01      t5     213.0  0.079861        1187    0.318334
# 6   2023-02-01      a3     193.0  0.195722         665    0.220494
# 7   2023-02-01     la6     193.0  0.100925         665    0.215436
# 8   2023-02-01      t5     193.0  0.137572         665    0.204096
# 9   2023-03-01      a3     181.0  0.111977         866    0.265193
# 10  2023-03-01     la6     181.0  0.076399         866    0.256988
# 11  2023-03-01      t5     181.0  0.088000         866    0.292427
# 12  2023-04-01      a3     117.0  0.091097        1135    0.221421
# 13  2023-04-01     la6     117.0  0.061329        1135    0.236270
# 14  2023-04-01      t5     117.0  0.065614        1135    0.283354
# 15  2023-05-01      a3     667.0  0.104142        1434    0.210834
# 16  2023-05-01     la6     667.0  0.041783        1434    0.215549
# 17  2023-05-01      t5     667.0  0.062718        1434    0.279731
# 18  2023-06-01      a3     447.0  0.092191        1243    0.200567
# 19  2023-06-01     la6     447.0  0.046229        1243    0.187021
# 20  2023-06-01      t5     447.0  0.061576        1243    0.175091
# 21  2023-07-01      a3     433.0  0.067678         939    0.197055
# 22  2023-07-01     la6     433.0  0.069231         939    0.179872
# 23  2023-07-01      t5     433.0  0.059783         939    0.204000
# 24  2023-08-01      a3     324.0  0.050766         784    0.217747
# 25  2023-08-01     la6     324.0  0.034461         784    0.213120
# 26  2023-08-01      t5     324.0  0.041725         784    0.290589
# 27  2023-09-01      a3     621.0  0.060023         803    0.155548
# 28  2023-09-01     la6     621.0  0.041176         803    0.125763
# 29  2023-09-01      t5     621.0  0.039526         803    0.242708
# 30  2023-10-01      a3     347.0  0.030660         746    0.164347
# 31  2023-10-01     la6     347.0  0.019393         746    0.127413
# 32  2023-10-01      t5     347.0  0.028969         746    0.219142
# 33  2023-11-01      a3     432.0  0.019408         792    0.117596
# 34  2023-11-01     la6     432.0  0.023669         792    0.092133
# 35  2023-11-01      t5     432.0  0.012626         792    0.172982
# 36  2023-12-01      a3     840.0  0.046748         615    0.159870
# 37  2023-12-01     la6     840.0  0.030598         615    0.174962
# 38  2023-12-01      t5     840.0  0.025210         615    0.202555
# 39  2024-01-01      a3     677.0  0.036585         677    0.214680
# 40  2024-01-01     la6     677.0  0.020185         677    0.172865
# 41  2024-01-01      t5     677.0  0.013462         677    0.200000
# 42  2024-02-01      a3     523.0  0.072816         923    0.105893
# 43  2024-02-01     la6     523.0  0.034589         923    0.148394
# 44  2024-02-01      t5     523.0  0.080503         923    0.170070
# 45  2024-03-01      a3     849.0  0.093842         584    0.128471
# 46  2024-03-01     la6     849.0  0.054995         584    0.148158
# 47  2024-03-01      t5     849.0  0.071656         584    0.131888
# 48  2024-04-01      a3     505.0  0.027273         731    0.180315
# 49  2024-04-01     la6     505.0  0.028005         731    0.342541
# 50  2024-04-01      t5     505.0  0.019174         731    0.234474
#
#     war_share_out_of_total
# 0                 0.019943
# 1                 0.013344
# 2                 0.011649
# 3                 0.022056
# 4                 0.025839
# 5                 0.025656
# 6                 0.037432
# 7                 0.021755
# 8                 0.028227
# 9                 0.025806
# 10                0.019705
# 11                0.025962
# 12                0.022167
# 13                0.013754
# 14                0.018753
# 15                0.022032
# 16                0.009053
# 17                0.017712
# 18                0.018519
# 19                0.008570
# 20                0.010878
# 21                0.012692
# 22                0.012732
# 23                0.012319
# 24                0.010930
# 25                0.007208
# 26                0.012239
# 27                0.009296
# 28                0.005196
# 29                0.009684
# 30                0.005084
# 31                0.002404
# 32                0.006412
# 33                0.002298
# 34                0.002194
# 35                0.002210
# 36                0.007503
# 37                0.005378
# 38                0.005182
# 39                0.007907
# 40                0.003518
# 41                0.002724
# 42                0.007735
# 43                0.005150
# 44                0.013795
# 45                0.012097
# 46                0.008173
# 47                0.009528
# 48                0.004957
# 49                0.009646
# 50                0.004548

# %% [markdown]
# Convert week df to panel

# %%
# Melting the dataframe to long format
df_long = pd.melt(week_agg, id_vars=['week', 'launched', 'fatalities'],
                  value_vars=['a3_share_with_ukraine', 'la6_share_with_ukraine', 't5_share_with_ukraine', 
                              'a3_share_class_1', 'la6_share_class_1', 't5_share_class_1',
                              'a3_war_share_out_of_total', 'la6_war_share_out_of_total', 't5_war_share_out_of_total'],
                  var_name='type', value_name='value')

# Extracting the 'a3', 't5', 'la6' part and the share type part
df_long[['share_type', 'type']] = df_long['type'].str.extract(r'(a3|la6|t5)_(.*)')

# Pivoting the dataframe to wide format again
df_panel = df_long.pivot_table(index=['week', 'launched', 'fatalities', 'share_type'], 
                               columns='type', values='value').reset_index()

# Reordering the columns
df_panel_week = df_panel[['week', 'share_type', 'launched', 
                     'share_with_ukraine', 'fatalities', 'share_class_1', 'war_share_out_of_total']]

# Renaming columns
df_panel_week.columns = ['week', 'channel', 'launched', 
                    'coverage', 'fatalities', 'war_images', 'war_share_out_of_total']

# %%
df_panel_week
# Out:
#            week channel  launched  coverage  fatalities  war_images  \
# 0    2022-12-05      a3      99.0  0.082251         313    0.143154
# 1    2022-12-05     la6      99.0  0.081761         313    0.225271
# 2    2022-12-05      t5      99.0  0.084158         313    0.156615
# 3    2022-12-12      a3     116.0  0.048458         282    0.213115
# 4    2022-12-12     la6     116.0  0.046429         282    0.173454
# ..          ...     ...       ...       ...         ...         ...
# 210  2024-04-22      a3      92.0  0.030973         135    0.228029
# 211  2024-04-22     la6      92.0  0.056818         135    0.327815
# 212  2024-04-22      t5      92.0  0.000000         135    0.338798
# 213  2024-04-29      a3      56.0  0.032258          67    0.250518
# 214  2024-04-29      t5      56.0       NaN          67    0.049180
#
#      war_share_out_of_total
# 0                  0.017424
# 1                  0.018501
# 2                  0.013284
# 3                  0.006019
# 4                  0.007953
# ..                      ...
# 210                0.007080
# 211                0.018750
# 212                0.005616
# 213                0.006452
# 214                0.000000
#
# [215 rows x 7 columns]

# %% [markdown]
# Save dataframes

# %%
df_panel_month.to_csv('data/monthly_panel.csv', index=False)
df_panel_week.to_csv('data/weekly_panel.csv', index=False)
